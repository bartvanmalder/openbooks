# %% [markdown]
# # Opensource notebook POC
# This is a sample notebook to demonstrate running on open notebook platforms like JupyterHub and Binder.
# Run it on Binder: URL-here

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.eye(10)
plt.plot(y)
plt.show()
